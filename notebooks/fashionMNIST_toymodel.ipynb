# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
from torch import nn, optim

# %%
# Download training data from open datasets.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Download test data from open datasets.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
batch_size = 64

# Create data loaders.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

def make_acc_dataset(model, dataset):
  n = len(dataset)
  for i in range(n):
      x, y = dataset[i][0], dataset[i][1]
      with torch.no_grad():
          pred = model(x)
      if (not(pred[0].argmax(0) - y)):
          dataset.targets[i] = 1
      else:
          dataset.targets[i] = 0
  return dataset

# %%
# Get cpu or gpu device for training.
device = "cpu"
print("Using {} device".format(device))
# Define model
class NeuralNetworkClass(nn.Module):
    def __init__(self):
        super(NeuralNetworkClass, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
            nn.ReLU()
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x).to(device)
        return logits

class_model = NeuralNetworkClass().to(device)
print(class_model)

class NeuralNetworkPred(nn.Module):
    def __init__(self):
        super(NeuralNetworkPred, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 2),
            nn.ReLU()
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x).to(device)
        return logits


pred_model = NeuralNetworkPred().to(device)
print(pred_model)
# Out:
# Using cpu device
# NeuralNetworkClass(
#   (flatten): Flatten()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#     (5): ReLU()
#   )
# )
# NeuralNetworkPred(
#   (flatten): Flatten()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=2, bias=True)
#     (5): ReLU()
#   )
# )

# %%
loss_fn_class = nn.CrossEntropyLoss()
optimizer_class = torch.optim.SGD(class_model.parameters(), lr=1e-3)
loss_fn_pred = nn.CrossEntropyLoss()
optimizer_pred = torch.optim.SGD(pred_model.parameters(), lr=1e-3)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
def test(dataloader, model, loss_fn, min_loss):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    if test_loss < min_loss:
        print(f"Early Stopping: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
        return 1
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return 0

def weight_reset(m):
    reset_parameters = getattr(m, "reset_parameters", None)
    if callable(reset_parameters):
        m.reset_parameters()

# %%
torch.save(class_model.state_dict(), f"blankallclass_model.pth")
torch.save(pred_model.state_dict(), f"blankpred_model.pth")

epochs = 50
model_gens = 10
for g in range(model_gens):
    # Reset all the models
    # Full 10 class
    print(f"New Gen Time \n")
    class_model = NeuralNetworkClass()
    class_model.load_state_dict(torch.load("blankallclass_model.pth"))
    loss_fn_class = nn.CrossEntropyLoss()
    optimizer_class = torch.optim.SGD(class_model.parameters(), lr=1e-3)
    # Just predict
    pred_model = NeuralNetworkPred()
    pred_model.load_state_dict(torch.load("blankpred_model.pth"))
    loss_fn_pred = nn.CrossEntropyLoss()
    optimizer_pred = torch.optim.SGD(pred_model.parameters(), lr=1e-3)
    for t in range(epochs):
        print(f"Epoch {t+1} of gen {g+1}\n-------------------------------")
        train(train_dataloader, class_model, loss_fn_class, optimizer_class)
        early_stopping = test(test_dataloader, class_model, loss_fn_class, 1)
        if early_stopping == 1 or t == epochs:
            torch.save(class_model.state_dict(), f"{g+1}_allclass_model.pth")
            print(f"Saved PyTorch Model State to {g+1}_allclass_model.pth")
            print(f"Predicting {g+1}\n-------------------------------")
            pred_train_dataset = make_acc_dataset(class_model,training_data)
            pred_test_dataset = make_acc_dataset(class_model,test_data)
            pred_train_dataloader = DataLoader(pred_train_dataset, batch_size=batch_size)
            pred_test_dataloader = DataLoader(pred_test_dataset, batch_size=batch_size)
            for p in range(epochs):
                print(f"Epoch {p+1} of gen {g+1} pred class \n-------------------------------")
                train(pred_train_dataloader, pred_model, loss_fn_pred, optimizer_pred)
                early_stopping = test(pred_test_dataloader, pred_model, loss_fn_pred, 0.5)
                if early_stopping == 1 or p == epochs:
                    torch.save(pred_model.state_dict(), f"{g+1}_pred_model.pth")
                    print(f"Saved PyTorch Model State to {g+1}_pred_model.pth")
                    break
            break


print("Done!")
# Out:
# New Gen Time
#
# Epoch 1 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 40.2%, Avg loss: 2.111051
#
# Epoch 2 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 41.5%, Avg loss: 1.963028
#
# Epoch 3 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 43.1%, Avg loss: 1.839952
#
# Epoch 4 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 45.5%, Avg loss: 1.711900
#
# Epoch 5 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 48.4%, Avg loss: 1.619149
#
# Epoch 6 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 49.7%, Avg loss: 1.550156
#
# Epoch 7 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 50.6%, Avg loss: 1.497672
#
# Epoch 8 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 51.4%, Avg loss: 1.457199
#
# Epoch 9 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 52.2%, Avg loss: 1.425224
#
# Epoch 10 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 52.7%, Avg loss: 1.398873
#
# Epoch 11 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 53.3%, Avg loss: 1.376237
#
# Epoch 12 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 53.8%, Avg loss: 1.356123
#
# Epoch 13 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 54.3%, Avg loss: 1.337748
#
# Epoch 14 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 56.4%, Avg loss: 1.273131
#
# Epoch 15 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 67.0%, Avg loss: 1.116484
#
# Epoch 16 of gen 1
# -------------------------------
# Test Error:
#  Accuracy: 68.2%, Avg loss: 1.014868
#
# Epoch 17 of gen 1
# -------------------------------
# Early Stopping:
#  Accuracy: 68.7%, Avg loss: 0.969131
#
# Saved PyTorch Model State to 1_allclass_model.pth
# Predicting 1
# -------------------------------
# Epoch 1 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.619226
#
# Epoch 2 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.605362
#
# Epoch 3 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.592703
#
# Epoch 4 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.581502
#
# Epoch 5 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 0.571563
#
# Epoch 6 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 70.7%, Avg loss: 0.560623
#
# Epoch 7 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 73.5%, Avg loss: 0.549488
#
# Epoch 8 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 74.7%, Avg loss: 0.538220
#
# Epoch 9 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 75.8%, Avg loss: 0.527043
#
# Epoch 10 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 76.2%, Avg loss: 0.516252
#
# Epoch 11 of gen 1 pred class
# -------------------------------
# Test Error:
#  Accuracy: 76.4%, Avg loss: 0.505769
#
# Epoch 12 of gen 1 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 76.6%, Avg loss: 0.495566
#
# Saved PyTorch Model State to 1_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.359380
#
# Epoch 2 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.307126
#
# Epoch 3 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.277708
#
# Epoch 4 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.256338
#
# Epoch 5 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.237851
#
# Epoch 6 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.220892
#
# Epoch 7 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.205493
#
# Epoch 8 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.191809
#
# Epoch 9 of gen 2
# -------------------------------
# Test Error:
#  Accuracy: 68.7%, Avg loss: 1.179965
#
# Epoch 10 of gen 2
# -------------------------------
# Early Stopping:
#  Accuracy: 69.2%, Avg loss: 0.808210
#
# Saved PyTorch Model State to 2_allclass_model.pth
# Predicting 2
# -------------------------------
# Epoch 1 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.616184
#
# Epoch 2 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.603531
#
# Epoch 3 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.592139
#
# Epoch 4 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.582024
#
# Epoch 5 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.573282
#
# Epoch 6 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 0.564756
#
# Epoch 7 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 70.2%, Avg loss: 0.555188
#
# Epoch 8 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.545404
#
# Epoch 9 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.535488
#
# Epoch 10 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.525779
#
# Epoch 11 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 75.7%, Avg loss: 0.516502
#
# Epoch 12 of gen 2 pred class
# -------------------------------
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.507581
#
# Epoch 13 of gen 2 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 76.1%, Avg loss: 0.499040
#
# Saved PyTorch Model State to 2_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.345951
#
# Epoch 2 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.296310
#
# Epoch 3 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.268749
#
# Epoch 4 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.249201
#
# Epoch 5 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.232574
#
# Epoch 6 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.217427
#
# Epoch 7 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.203446
#
# Epoch 8 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.190847
#
# Epoch 9 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.179697
#
# Epoch 10 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.170026
#
# Epoch 11 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.161758
#
# Epoch 12 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.154746
#
# Epoch 13 of gen 3
# -------------------------------
# Test Error:
#  Accuracy: 69.2%, Avg loss: 1.148705
#
# Epoch 14 of gen 3
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.676694
#
# Saved PyTorch Model State to 3_allclass_model.pth
# Predicting 3
# -------------------------------
# Epoch 1 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.589856
#
# Epoch 2 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580378
#
# Epoch 3 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572219
#
# Epoch 4 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.564813
#
# Epoch 5 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558254
#
# Epoch 6 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552634
#
# Epoch 7 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.547861
#
# Epoch 8 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543730
#
# Epoch 9 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540011
#
# Epoch 10 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536545
#
# Epoch 11 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533202
#
# Epoch 12 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529905
#
# Epoch 13 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526630
#
# Epoch 14 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523358
#
# Epoch 15 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520084
#
# Epoch 16 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516819
#
# Epoch 17 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513497
#
# Epoch 18 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509583
#
# Epoch 19 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505741
#
# Epoch 20 of gen 3 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.501956
#
# Epoch 21 of gen 3 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498319
#
# Saved PyTorch Model State to 3_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.242990
#
# Epoch 2 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.198440
#
# Epoch 3 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.174519
#
# Epoch 4 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160116
#
# Epoch 5 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.149577
#
# Epoch 6 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.140636
#
# Epoch 7 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.132515
#
# Epoch 8 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125169
#
# Epoch 9 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118517
#
# Epoch 10 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112505
#
# Epoch 11 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107068
#
# Epoch 12 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102127
#
# Epoch 13 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097640
#
# Epoch 14 of gen 4
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093589
#
# Epoch 15 of gen 4
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.643638
#
# Saved PyTorch Model State to 4_allclass_model.pth
# Predicting 4
# -------------------------------
# Epoch 1 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.589934
#
# Epoch 2 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580466
#
# Epoch 3 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572311
#
# Epoch 4 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.564909
#
# Epoch 5 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558353
#
# Epoch 6 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552735
#
# Epoch 7 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.547962
#
# Epoch 8 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543828
#
# Epoch 9 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540104
#
# Epoch 10 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536632
#
# Epoch 11 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533284
#
# Epoch 12 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529981
#
# Epoch 13 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526698
#
# Epoch 14 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523415
#
# Epoch 15 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520134
#
# Epoch 16 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516860
#
# Epoch 17 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.8%, Avg loss: 0.513481
#
# Epoch 18 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509500
#
# Epoch 19 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.505628
#
# Epoch 20 of gen 4 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.501847
#
# Epoch 21 of gen 4 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498210
#
# Saved PyTorch Model State to 4_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.243303
#
# Epoch 2 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.198774
#
# Epoch 3 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.174864
#
# Epoch 4 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160461
#
# Epoch 5 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.149909
#
# Epoch 6 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.140948
#
# Epoch 7 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.132808
#
# Epoch 8 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125439
#
# Epoch 9 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118764
#
# Epoch 10 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112725
#
# Epoch 11 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107265
#
# Epoch 12 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102296
#
# Epoch 13 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097789
#
# Epoch 14 of gen 5
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093726
#
# Epoch 15 of gen 5
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.666101
#
# Saved PyTorch Model State to 5_allclass_model.pth
# Predicting 5
# -------------------------------
# Epoch 1 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.589923
#
# Epoch 2 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580449
#
# Epoch 3 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572286
#
# Epoch 4 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.564876
#
# Epoch 5 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558314
#
# Epoch 6 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552693
#
# Epoch 7 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.547917
#
# Epoch 8 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543782
#
# Epoch 9 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540059
#
# Epoch 10 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536587
#
# Epoch 11 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533240
#
# Epoch 12 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529939
#
# Epoch 13 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526657
#
# Epoch 14 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523376
#
# Epoch 15 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520101
#
# Epoch 16 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516836
#
# Epoch 17 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513529
#
# Epoch 18 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509647
#
# Epoch 19 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505806
#
# Epoch 20 of gen 5 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.502006
#
# Epoch 21 of gen 5 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498361
#
# Saved PyTorch Model State to 5_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.243261
#
# Epoch 2 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.198702
#
# Epoch 3 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.174778
#
# Epoch 4 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160370
#
# Epoch 5 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.149820
#
# Epoch 6 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.140866
#
# Epoch 7 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.132732
#
# Epoch 8 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125376
#
# Epoch 9 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118710
#
# Epoch 10 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112684
#
# Epoch 11 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107237
#
# Epoch 12 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102278
#
# Epoch 13 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097785
#
# Epoch 14 of gen 6
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093729
#
# Epoch 15 of gen 6
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.677850
#
# Saved PyTorch Model State to 6_allclass_model.pth
# Predicting 6
# -------------------------------
# Epoch 1 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.590059
#
# Epoch 2 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580597
#
# Epoch 3 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572427
#
# Epoch 4 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.565009
#
# Epoch 5 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558436
#
# Epoch 6 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552806
#
# Epoch 7 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.548020
#
# Epoch 8 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543875
#
# Epoch 9 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540143
#
# Epoch 10 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536662
#
# Epoch 11 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533306
#
# Epoch 12 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529997
#
# Epoch 13 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526706
#
# Epoch 14 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523416
#
# Epoch 15 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520131
#
# Epoch 16 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516857
#
# Epoch 17 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513540
#
# Epoch 18 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509642
#
# Epoch 19 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505790
#
# Epoch 20 of gen 6 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.501983
#
# Epoch 21 of gen 6 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498331
#
# Saved PyTorch Model State to 6_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.243739
#
# Epoch 2 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.199142
#
# Epoch 3 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.175184
#
# Epoch 4 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160745
#
# Epoch 5 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.150168
#
# Epoch 6 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.141188
#
# Epoch 7 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.133035
#
# Epoch 8 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125659
#
# Epoch 9 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118975
#
# Epoch 10 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112931
#
# Epoch 11 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107466
#
# Epoch 12 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102490
#
# Epoch 13 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097981
#
# Epoch 14 of gen 7
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093912
#
# Epoch 15 of gen 7
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.677849
#
# Saved PyTorch Model State to 7_allclass_model.pth
# Predicting 7
# -------------------------------
# Epoch 1 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.589923
#
# Epoch 2 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580449
#
# Epoch 3 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572286
#
# Epoch 4 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.564876
#
# Epoch 5 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558314
#
# Epoch 6 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552693
#
# Epoch 7 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.547917
#
# Epoch 8 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543782
#
# Epoch 9 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540059
#
# Epoch 10 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536587
#
# Epoch 11 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533240
#
# Epoch 12 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529939
#
# Epoch 13 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526657
#
# Epoch 14 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523376
#
# Epoch 15 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520101
#
# Epoch 16 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516836
#
# Epoch 17 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513529
#
# Epoch 18 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509647
#
# Epoch 19 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505806
#
# Epoch 20 of gen 7 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.502006
#
# Epoch 21 of gen 7 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498361
#
# Saved PyTorch Model State to 7_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.243261
#
# Epoch 2 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.198702
#
# Epoch 3 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.174778
#
# Epoch 4 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160370
#
# Epoch 5 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.149820
#
# Epoch 6 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.140866
#
# Epoch 7 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.132732
#
# Epoch 8 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125376
#
# Epoch 9 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118710
#
# Epoch 10 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112684
#
# Epoch 11 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107237
#
# Epoch 12 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102278
#
# Epoch 13 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097785
#
# Epoch 14 of gen 8
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093729
#
# Epoch 15 of gen 8
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.677850
#
# Saved PyTorch Model State to 8_allclass_model.pth
# Predicting 8
# -------------------------------
# Epoch 1 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.590059
#
# Epoch 2 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580597
#
# Epoch 3 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572427
#
# Epoch 4 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.565009
#
# Epoch 5 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558436
#
# Epoch 6 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552806
#
# Epoch 7 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.548020
#
# Epoch 8 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543875
#
# Epoch 9 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540143
#
# Epoch 10 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536662
#
# Epoch 11 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533306
#
# Epoch 12 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529997
#
# Epoch 13 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526706
#
# Epoch 14 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523416
#
# Epoch 15 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520131
#
# Epoch 16 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516857
#
# Epoch 17 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513540
#
# Epoch 18 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509642
#
# Epoch 19 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505790
#
# Epoch 20 of gen 8 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.501983
#
# Epoch 21 of gen 8 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498331
#
# Saved PyTorch Model State to 8_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.243739
#
# Epoch 2 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.199142
#
# Epoch 3 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.175184
#
# Epoch 4 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160745
#
# Epoch 5 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.150168
#
# Epoch 6 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.141188
#
# Epoch 7 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.133035
#
# Epoch 8 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125659
#
# Epoch 9 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118975
#
# Epoch 10 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112931
#
# Epoch 11 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107466
#
# Epoch 12 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102490
#
# Epoch 13 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097981
#
# Epoch 14 of gen 9
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093912
#
# Epoch 15 of gen 9
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.677849
#
# Saved PyTorch Model State to 9_allclass_model.pth
# Predicting 9
# -------------------------------
# Epoch 1 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.589923
#
# Epoch 2 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580449
#
# Epoch 3 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572286
#
# Epoch 4 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.564876
#
# Epoch 5 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558314
#
# Epoch 6 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552693
#
# Epoch 7 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.547917
#
# Epoch 8 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543782
#
# Epoch 9 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540059
#
# Epoch 10 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536587
#
# Epoch 11 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533240
#
# Epoch 12 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529939
#
# Epoch 13 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526657
#
# Epoch 14 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523376
#
# Epoch 15 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520101
#
# Epoch 16 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516836
#
# Epoch 17 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513529
#
# Epoch 18 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509647
#
# Epoch 19 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505806
#
# Epoch 20 of gen 9 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.502006
#
# Epoch 21 of gen 9 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498361
#
# Saved PyTorch Model State to 9_pred_model.pth
# New Gen Time
#
# Epoch 1 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.243261
#
# Epoch 2 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.198702
#
# Epoch 3 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.174778
#
# Epoch 4 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.160370
#
# Epoch 5 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.149820
#
# Epoch 6 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.140866
#
# Epoch 7 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.132732
#
# Epoch 8 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.125376
#
# Epoch 9 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.118710
#
# Epoch 10 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.112684
#
# Epoch 11 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.107237
#
# Epoch 12 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.102278
#
# Epoch 13 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.097785
#
# Epoch 14 of gen 10
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 1.093729
#
# Epoch 15 of gen 10
# -------------------------------
# Early Stopping:
#  Accuracy: 72.7%, Avg loss: 0.677850
#
# Saved PyTorch Model State to 10_allclass_model.pth
# Predicting 10
# -------------------------------
# Epoch 1 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.590059
#
# Epoch 2 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.580597
#
# Epoch 3 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.572427
#
# Epoch 4 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.565009
#
# Epoch 5 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.558436
#
# Epoch 6 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.552806
#
# Epoch 7 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.548020
#
# Epoch 8 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.543875
#
# Epoch 9 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.540143
#
# Epoch 10 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.536662
#
# Epoch 11 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.533306
#
# Epoch 12 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.529997
#
# Epoch 13 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.526706
#
# Epoch 14 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.523416
#
# Epoch 15 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.520131
#
# Epoch 16 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.516857
#
# Epoch 17 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.513540
#
# Epoch 18 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.509642
#
# Epoch 19 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.505790
#
# Epoch 20 of gen 10 pred class
# -------------------------------
# Test Error:
#  Accuracy: 72.6%, Avg loss: 0.501983
#
# Epoch 21 of gen 10 pred class
# -------------------------------
# Early Stopping:
#  Accuracy: 72.8%, Avg loss: 0.498331
#
# Saved PyTorch Model State to 10_pred_model.pth
# Done!
